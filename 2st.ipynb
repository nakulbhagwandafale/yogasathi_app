# %%
pip install -U transformers datasets accelerate scikit-learn pandas
# Out:
# Requirement already satisfied: transformers in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (4.56.1)
# Requirement already satisfied: datasets in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (4.0.0)
# Requirement already satisfied: accelerate in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (1.4.0)
# Collecting accelerate
#   Downloading accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pandas in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Collecting pandas
#   Using cached pandas-2.3.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.13.2)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: psutil in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (2.6.0+cu118)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\nakul\appdata\roaming\python\python312\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.6)
# Requirement already satisfied: six>=1.5 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nakul\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: networkx in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (71.0.4)
# Requirement already satisfied: sympy==1.13.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.5)
# Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
# Downloading scikit_learn-1.7.2-cp312-cp312-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 1.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/8.7 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.7 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.7 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.4/8.7 MB 2.0 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.7 MB 2.0 MB/s eta 0:00:03
#    --------------- ------------------------ 3.4/8.7 MB 2.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/8.7 MB 2.0 MB/s eta 0:00:03
#    ------------------- -------------------- 4.2/8.7 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 4.7/8.7 MB 2.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.0/8.7 MB 2.0 MB/s eta 0:00:02
#    ------------------------- -------------- 5.5/8.7 MB 2.0 MB/s eta 0:00:02
#    -------------------------- ------------- 5.8/8.7 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.7 MB 2.0 MB/s eta 0:00:02
#    ------------------------------ --------- 6.6/8.7 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 7.1/8.7 MB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.7 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.9/8.7 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 2.0 MB/s  0:00:04
# Using cached pandas-2.3.2-cp312-cp312-win_amd64.whl (11.0 MB)
# Installing collected packages: scikit-learn, pandas, accelerate
#
#   Attempting uninstall: scikit-learn
#
#     Found existing installation: scikit-learn 1.5.2
#
#    ---------------------------------------- 0/3 [scikit-learn]
#     Uninstalling scikit-learn-1.5.2:
#    ---------------------------------------- 0/3 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.5.2
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#    ---------------------------------------- 0/3 [scikit-learn]
#   Attempting uninstall: pandas
#    ---------------------------------------- 0/3 [scikit-learn]
#     Found existing installation: pandas 2.2.2
#    ---------------------------------------- 0/3 [scikit-learn]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#     Uninstalling pandas-2.2.2:
#    ------------- -------------------------- 1/3 [pandas]
#       Successfully uninstalled pandas-2.2.2
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#    ------------- -------------------------- 1/3 [pandas]
#   Attempting uninstall: accelerate
#    ------------- -------------------------- 1/3 [pandas]
#    -------------------------- ------------- 2/3 [accelerate]
#     Found existing installation: accelerate 1.4.0
#    -------------------------- ------------- 2/3 [accelerate]
#     Uninstalling accelerate-1.4.0:
#    -------------------------- ------------- 2/3 [accelerate]
#       Successfully uninstalled accelerate-1.4.0
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    -------------------------- ------------- 2/3 [accelerate]
#    ---------------------------------------- 3/3 [accelerate]
#
# Successfully installed accelerate-1.10.1 pandas-2.3.2 scikit-learn-1.7.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages\~andas'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ultralytics 8.2.87 requires numpy<2.0.0,>=1.23.0, but you have numpy 2.2.6 which is incompatible.
# ultralytics 8.2.87 requires torch<2.4.0,>=1.8.0; sys_platform == "win32", but you have torch 2.6.0+cu118 which is incompatible.

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (2.6.0+cu118)
# Requirement already satisfied: torchvision in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (0.21.0+cu118)
# Requirement already satisfied: filelock in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch) (71.0.4)
# Requirement already satisfied: sympy==1.13.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
import torch
print(torch.__version__)        # PyTorch version
print(torch.version.cuda)       # CUDA version
print(torch.cuda.is_available())# GPU available or not
print(torch.cuda.get_device_name(0))  # तुझा GPU नाव
# Out:
# 2.6.0+cu118
# 11.8
# True
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# !pip uninstall transformers -y
# !pip install -U transformers
# Out:
# Found existing installation: transformers 4.56.1
# Uninstalling transformers-4.56.1:
#   Successfully uninstalled transformers-4.56.1
# Collecting transformers
#   Using cached transformers-4.56.1-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: filelock in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.13.2)
# Requirement already satisfied: colorama in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nakul\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nakul\appdata\roaming\python\python312\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nakul\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2025.4.26)
# Using cached transformers-4.56.1-py3-none-any.whl (11.6 MB)
# Installing collected packages: transformers
# Successfully installed transformers-4.56.1
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (C:\Users\nakul\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
# !pip cache purge
# Out:
# Files removed: 718 (3064.6 MB)
